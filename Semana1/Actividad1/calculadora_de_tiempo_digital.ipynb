# %% [markdown]
# # Calculadora Interactiva en Python.
#
# **reto** Desarrollar una **calculadora interactiva en Python** que permita registrar el tiempo diario (en horas o fracciones de hora) que una persona dedica a distintas plataformas digitales: redes sociales, mensajería, servicios de streaming, videojuegos, entre otras. El programa debe capturar los datos, procesarlos y mostrar un resumen claro y ordenado de los resultados.

# %% [markdown]
# Modelo EPS:
# 1. **Entrada (Input):**
#
# - Nombreusuario: nombre de usuario (Variable caracter)
# - t_spotify: horas al día en Spotify (variable float)
# - t_tiktok: horas al día en tiktok (variable float)
# - t_instagram: horas al día en instagram (variable float)
# - t_plataforma_streaming: horas al día en plataformas de streaming (variable float)
# - t_whats: horas al día en WhatsApp (variable float)
#
# 2. **Proceso (Processing):**
#
# - Cálculo del tiempo total:
# t_total=t_spotify+t_tiktok+t_instagram+t_plataforma_streaming+t_whats
#
# - Cálculo del porcentaje diario:
# porcentaje_TD= (t_total/24) * 100
#
# 3. **Salida (Output):**
# Mensaje impreso en la pantalla que contiene:
#
# - nombreusuario: El nombre del usuario
# - t_total: El tiempo total redondeado a dos decimales
# - porcentaje_TD: El porcentaje total de su día redondeado a dos decimales

# %% [markdown]
# #### Pasos en lenguaje natural:
#
# 1. Solicitar el nombre de usuario
# 2. Solicitar el tiempo escuchado en Spotify en horas por día
# 3. Solicitar el tiempo en pantalla en tiktok en horas por día
# 4. Solicitar el tiempo en pantalla en instagram en horas por día
# 5. Solicitar el tiempo en pantalla en plataformas de streaming en horas
# 6. Solicitar el tiempo que pasó en WhatsApp en horas por día
# 7. Calcular tiempo total sumando los datos ingresados por el usuario del paso 2 al 6
# 8. Calcular el porcentaje que representa del total de su día mediante la fórmula: (t_total/24) * 100
# 9. Mostrar el nombre del usuario, las horas totales, y el porcentaje que representa

# %% [markdown]
# ### PseudoCódigo (Pseint):
#
# Algoritmo CalculadoraDeTiempoDigital
#
# Escribir "Ingrese su nombre de usuario"
#
# Leer nombreusuario
#
# Escribir "Ingrese el tiempo que ha escuchado Spotify en horas por día: "
#
# Leer t_spotify
#
# Escribir "Ingrese el tiempo en pantalla que paso TikTok en horas por día: "
#
# Leer t_tiktok
#
# Escribir "Ingrese el tiempo en pantalla en instagram en horas por día: "
#
# Leer t_instagram
#
# Escribir "Ingrese el tiempo en pantalla en plataformas de streaming en horas por día"
#
# Leer t_plataforma_streaming
#
# Escribir "Ingrese el tiempo que paso en WhatsApp en horas por día: "
#
# Leer t_whats
#
# t_total <- t_spotify + t_tiktok + t_instagram + t_plataforma_streaming + t_whats
#
# porcentaje_TD <- (t_total/24) * 100
#
#
# // Resultado redondeado a dos decimales
#
#
# Escribir "El usuario: ", nombreusuario, " acumuló un tiempo total de: ", t_total, " horas al día en redes sociales y plataformas de streaming, lo que representa un ", porcentaje_TD, "% del tiempo total de su día"
#
#
# FinAlgoritmo

# %%
#Pedir el nombre de usuario con la función input() y guardarlo en la variable nombreusuario.
nombreusuario=input("Ingrese su nombre de usuario: ")
#Pedir el tiempo que ha escuchado en diferentes plataformas en horas por día, con la función float() puede ingresar horas fraccionarias
#Y Guardarlo en la variable t_spotify,t_tiktok,t_instagram,t_plataforma_streaming,t_whats
t_spotify=float(input("Ingrese el tiempo que ha escuchado Spotify en horas por día: "))
t_tiktok=float(input("Ingrese el tiempo en pantalla que paso TikTok en horas por día: "))
t_instagram=float(input("Ingrese el tiempo en pantalla que paso Instagram en horas por día: "))
t_plataforma_streaming=float(input("Ingrese el tiempo que paso en plataformas de streaming en horas por día: "))
t_whats=float(input("Ingrese el tiempo que paso en WhatsApp en horas por día: "))
#Calcular el tiempo total que paso en redes sociales y plataformas de streaming sumando las variables y guardarlo en la variable t_total.
t_total=t_spotify+t_tiktok+t_instagram+t_plataforma_streaming+t_whats
porcentaje_TD= (t_total/24) * 100
#Imprimir el resultado en pantalla con la función print() y usando f-strings para mostrar el nombre de usuario, el tiempo total y el porcentaje del tiempo total del día que paso en redes sociales y plataformas de streaming que fueron reducidos a dos decimales con la funcion :.2f
print(f"El usuario {nombreusuario} acumuló un tiempo total de {t_total:.2f} horas al día en redes sociales y plataformas de streaming, lo que representa un {porcentaje_TD:.2f}% del tiempo total de su día.")
# Out:
# El usuario maria acumuló un tiempo total de 11.30 horas al día en redes sociales y plataformas de streaming, lo que representa un 47.08% del tiempo total de su día.
