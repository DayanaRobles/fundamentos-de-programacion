# %% [markdown]
# ## BLOQUE 1 · DISEÑO ALGORÍTMICO, EPS Y PSEINT (TEMAS 1 Y 2)
#
# ### Ejercicio 1: Algoritmo con decisión para descuento por monto
# **Enunciado:** Escribe en lenguaje natural los pasos del algoritmo (modelo Entrada-Proceso-Salida) para que una tienda aplique un 10% de descuento cuando la compra sea de $300 o más, y muestre el monto del descuento y el total a pagar.
# **Entrada:** `monto = 500`
# **Proceso:** `descuento = 500 * 0.10`, `total = 500 - 50`
# **Salida:** `Monto: 500. Descuento: 50.0. Total a pagar: 450.0`

# %% [markdown]
# ### Ejercicio 2: Pseudocódigo en PSeInt que clasifica un número
# **Enunciado:** Escribe el pseudocódigo en PSeInt que lea un número entero y determine si es positivo, negativo o cero, usando una estructura `Si-Entonces-Sino`.
# **Entrada:** `-5`
# **Salida:** `El número -5 es negativo`

# %%
num_e=int(input("Ingresa número a evaluar: "))
if num_e == 0:
    print(f"El numero ingresado es: {num_e}")
elif num_e > 0:
    print(f"El numero {num_e} es positivo")
else:
    print(f"El numero {num_e} es negativo")

# %% [markdown]
# ### Ejercicio 3: Pseudocódigo en PSeInt con ciclo Mientras y acumulador
# **Enunciado:** Escribe el pseudocódigo en PSeInt que sume números enteros hasta que el usuario ingrese `0`, y muestre la suma acumulada.
# **Entrada:** `5`, `8`, `3`, `0`
# **Proceso:** `suma = 5 + 8 + 3`
# **Salida:** `La suma es: 16`

# %%
suma=0
while True:
    num= int(input("ingrese numero"))
    if num !=0:
        suma += num
    else:
        print ("Finalizó el proceso.")
        break
print(f"La suma es: {suma}")

# %% [markdown]
# ### Ejercicio 4: Pseudocódigo en PSeInt con ciclo Para (tabla de multiplicar)
# **Enunciado:** Escribe el pseudocódigo en PSeInt que genere la tabla de multiplicar del 7 desde `7 x 1` hasta `7 x 10`.
# **Entrada:** `7`
# **Salida:** `7 x 1 = 7`, `7 x 2 = 14`, `...`, `7 x 10 = 70`

# %%
num=7
res=0
for i in range (1, 10+1):
    res= num * i 
    print(f"{num} * {i} = {res}")

# %% [markdown]
# ### Ejercicio 5: Algoritmo natural del registro de ventas del día
# **Enunciado:** Diseña el algoritmo paso a paso (en lenguaje natural) para registrar ventas del día con un acumulador que se detiene cuando se ingresa `0`, y muestra el total. Identifica las fases Entrada, Proceso y Salida.
# **Entrada:** `120`, `80`, `200`, `0`
# **Proceso:** `total = 120 + 80 + 200`
# **Salida:** `Total de ventas del día: 400`

# %% [markdown]
# ### Ejercicio 7: Número par o impar
# **Enunciado:** Crea un programa que pida un número entero y muestre si es par o impar usando el operador módulo `%`.
# **Entrada:** `14`
# **Proceso:** `14 % 2 = 0`
# **Salida:** `14 es un número par`

# %%
num_usurario=int(input("Ingrese un número entero para saber si es par o impar: "))

if num_usurario%2==0: 
    print(f"{num_usurario} es número par")
else:
    print(f"{num_usurario} es número impar")

# %% [markdown]
# ### Ejercicio 8: El mayor de tres números
# **Enunciado:** Crea un programa que pida tres números y determine cuál es el mayor, usando decisiones anidadas o comparaciones con `and`.
# **Entrada:** `12`, `7`, `9`
# **Salida:** `El mayor es: 12`

# %%
num1=int(input("Ingrese un número:"))
num2=int(input("Ingrese un número:"))
num3=int(input("Ingrese un número:"))
if num1!=num2 and num1!=num3 and num2!=num3:
    if num1>num2 and num1>num3:
        print(f"El mayor es:{num1}")
    elif num2>num2 and num2>num3:
        print(f"El mayor es:{num2}")
    elif num3>num2 and num3>num1:
        print(f"El mayor es:{num3}")
else:
    if num1==num2 and num1> num3:
        print(f"Hay dos numeros mayores que se repiten. El numero mayor es:{num1} y {num2}")
    elif num2==num3 and num2 > num1:
        print(f"Hay dos numeros mayores que se repiten. El numero mayor es:{num2}, {num3}")
    else:
        print(f"Hay dos numeros mayores que se repiten. El numero mayor es: {num1}, {num3}")

# %% [markdown]
# ### Ejercicio 11: Suma con centinela 0
# **Enunciado:** Crea un programa que sume números positivos ingresados por el usuario y se detenga cuando ingrese `0`, mostrando la suma total.
# **Entrada:** `4`, `6`, `10`, `0`
# **Proceso:** `suma = 4 + 6 + 10`
# **Salida:** `La suma es: 20`

# %%
num=0
while True:
    
    while True:
        num=int(input("Ingrese un número:"))
        if num < 0:
            continue
        else:
            break
    num+=1
print(f"la suma es{num}")

# %%
numsuma = 0
while True: 
    num=float(input("Ingrese un número:"))
    if num != 0:
        numsuma = num + numsuma
    else:
        break
    
print(f"la suma es {numsuma:.2f}")
print("Proceso Finalizado")

# %%
numsuma = 0
while True: 
    while True:
        num=float(input("Ingrese un número:"))
        if num < 0:
             print("No se puede sumar números negativos.\n---Intente de nuevo---")
             continue
        else:
            break
    
    if num != 0:
        numsuma = num + numsuma
    else:
        break
    
print(f"la suma es {numsuma:.2f}")
print("Proceso Finalizado")

# %% [markdown]
# ### Ejercicio 23: Promedio con validación de rango
# **Enunciado:** Crea un programa que capture calificaciones hasta ingresar `-1`. Si una calificación está fuera del rango 0 a 10, muestra un error y no la considera. Al final muestra el promedio de las válidas.
# **Entrada:** `8`, `12` (inválida), `9`, `-1`
# **Proceso:** válidas `{8, 9}`, `promedio = 17 / 2`
# **Salida:**
# ```
# Error: calificación fuera de rango (0-10)
# El promedio es: 8.5

# %% [markdown]
# ### Ejercicio 24: Minicalculadora con menú y ciclo while
# **Enunciado:** Crea un programa con un menú: `1` suma, `2` resta, `3` multiplicación, `4` salir. Para cada operación pide dos números y muestra el resultado; repite hasta elegir salir.
# **Entrada:** opción `1` con `10` y `5`, luego opción `3` con `4` y `2`, luego opción `4`
# **Proceso:** `10 + 5 = 15`, `4 * 2 = 8`
# **Salida:**
# ```
# Suma: 15.0
# Multiplicación: 8.0
# Fin del programa
# ```

# %%
while True: 
    print("\nMenu")
    print("Presiona:\n (1) Suma\n (2)Resta\n (3)Multiplicación\n (4) salir\n=======\n")
    while True:
        ope=int(input("Opción:"))
        if ope == 1 or ope == 2 or ope == 3 or ope == 4:
            break
        else:
            continue
    if ope==4:
         print("Proceso finalizado")
         break

    resultado = 0
    num=float(input("Ingrese un número 1:"))
    num2=float(input("Ingrese un número 2:"))


    if ope==1:
        resultado = num + num2
        print("Suma: ")

    elif ope==2:
        resultado = num - num2
        print("Resta: ")

    elif ope==3:
        print("Multiplicación: ")
        resultado = num * num2

    print(f"=======\n{resultado:.2f}\n =======")

# %% [markdown]
# # EXTRAS

# %% [markdown]
# ### Ejercicio 2: Años bisiestos en un rango
# **Enunciado:** Crea un programa que pida dos años (inicio y fin) y muestre en una línea todos los años bisiestos de ese rango. Regla: un año es bisiesto si es divisible entre 4 pero no entre 100, o si es divisible entre 400. Usa el `for` con `range` y operadores lógicos (`and`/`or`).
# **Entrada:** `2000` y `2010`
# **Proceso:** `2000 % 400 == 0` (bisiesto), `2004 % 4 == 0` y `2004 % 100 != 0` (bisiesto), `2008` (bisiesto)
# **Salida:** `Años bisiestos: 2000, 2004, 2008`

# %%
a_in=int(input("Ingrese año inicial: "))
a_fin=int(input("Ingrese año final: "))
a = 0
for anios in range (a_in, a_fin + 1 ):
    if a % 4 == 0 and a % 100 != 0 :
        print(f"Años bisietos: {a}")

# %% [markdown]
# ### Ejercicio 3: Contador de dígitos
# **Enunciado:** Crea un programa que pida un número entero positivo y cuántos dígitos tiene, usando `while` con el operador división entera `//` (cada iteración elimina el último dígito).
# **Entrada:** `4572`
# **Proceso:** `4572 -> 457 -> 45 -> 4 -> 0` (4 eliminaciones)
# **Salida:** `El número 4572 tiene 4 dígitos`

# %%
num=int(input("Ingrese número: "))
numeroriginal = num
contador = 0
while num > 0:
    num = num // 10
    contador += 1

print(f"el numero {numeroriginal} tiene {contador} dígitos")

# %% [markdown]
# ### Ejercicio 4: Suma de dígitos
# **Enunciado:** Crea un programa que pida un número entero positivo y calcule la suma de sus dígitos usando `while`, el módulo `%` para extraer el último dígito y `//` para eliminarlo.
# **Entrada:** `4729`
# **Proceso:** `4 + 7 + 2 + 9 = 22`
# **Salida:** `La suma de los dígitos de 4729 es: 22`

# %%
num=int(input("Ingrese número: "))
numeroriginal=num
suma=0
while num > 0:
    digito= num % 10
    suma= suma + digito 
    num = num // 10
print("La suma de los digitos es:", suma)

# %% [markdown]
# ### Ejercicio 5: Número invertido
# **Enunciado:** Crea un programa que pida un número entero positivo y muestre sus dígitos en orden inverso. Construye el nuevo número en un acumulador con la fórmula `invertido = invertido * 10 + digito`.
# **Entrada:** `1234`
# **Proceso:** `4`, luego `43`, luego `432`, luego `4321`
# **Salida:** `El número invertido de 1234 es 4321`

# %%
num=int(input("Ingrese número: "))
invertido=0

while num != 0:
    r = num % 10
    invertido = invertido * 10 + r
    num = num//10
print (invertido)

# %% [markdown]
# ### Ejercicio 6: División con restas sucesivas
# **Enunciado:** Sin usar los operadores `/` ni `//`, calcula el cociente y el residuo de una división entre enteros positivos restando el divisor al dividendo con un `while`; el cociente es la cantidad de restas realizadas.
# **Entrada:** `17` y `5`
# **Proceso:** `17-5=12`, `12-5=7`, `7-5=2` (3 restas, ya no se puede restar más)
# **Salida:** `17 ÷ 5 = 3 con residuo 2`

# %%
dividendo=int(input("Ingrese número 1: "))
divisor=int(input("Ingrese número 2: "))
contador = 0
residuo=num1
while residuo >= divisor:
    residuo=residuo-divisor
    contador += 1
print(f"{dividendo}/{divisor}={contador}")
print(residuo)

# %% [markdown]
# ### Ejercicio 7: Desglose de billetes
# **Enunciado:** Un cajero entrega el monto solicitado con la menor cantidad de billetes posibles. Crea un programa que pida un monto (múltiplo de 10) y muestre cuántos billetes de `$500`, `$200`, `$100`, `$50`, `$20` y monedas de `$10` entregará, usando `//` y `%`.
# **Entrada:** `1380`
# **Proceso:** `1380 // 500 = 2` (restan 380), `380 // 200 = 1` (restan 180), y así sucesivamente
# **Salida:**
# ```
# Billetes de $500: 2
# Billetes de $200: 1
# Billetes de $100: 1
# Billetes de $50: 1
# Billetes de $20: 1
# Monedas de $10: 1
# ```

# %%
billetes_500 = 0
billetes_200 = 0
billetes_100 = 0
billetes_50 = 0
billetes_20 = 0
billetes_10 = 0
solomonedad=True
monto_retiro = int(input("Ingrese monto a retirar: "))
montorestante = monto_retiro

while montorestante >= 10:
    solomonedad=False
    if montorestante>=500:
        billetes_500 = montorestante // 500
        montorestante = montorestante % 500
    elif montorestante>=200:
        billetes_200 =  montorestante // 200
        montorestante = montorestante % 200
    elif montorestante>=100:
        billetes_100 =  montorestante // 100
        montorestante = montorestante % 100
    elif montorestante>=50:
        billetes_50 =  montorestante // 50
        montorestante = montorestante % 50
    elif montorestante>=20:
        billetes_20 =  montorestante // 20
        montorestante = montorestante % 20
    elif montorestante>=10:
        billetes_10 =  montorestante // 10
        montorestante = montorestante % 10
if  not solomonedad : 
    print(f" Billetes 500: {billetes_500}\n Billetes 200: {billetes_200}\n Billetes 100: {billetes_100}\n billetes 50: {billetes_50}\n billetes 20: {billetes_20}\n billetes 10: {billetes_10}")
print(" Monedas: ", montorestante)

# %% [markdown]
# ## BLOQUE 3 · FOR, ACUMULADORES Y SERIES NUMÉRICAS
#
# ### Ejercicio 8: Potencia sin usar **
# **Enunciado:** Crea un programa que pida una base y un exponente entero positivo, y calcule la potencia mediante multiplicaciones sucesivas con un `for` y un acumulador (sin usar el operador `**`).
# **Entrada:** base `3`, exponente `4`
# **Proceso:** `3 * 3 = 9`, `9 * 3 = 27`, `27 * 3 = 81`
# **Salida:** `3 elevado a 4 = 81`

# %%
base_num=int(input("Ingrese número base: "))
exponente_num=int(input("Ingrese número exponencial"))
num_multiplicado = base_num

for i in range(1,exponente_num):
   num_multiplicado = num_multiplicado * base_num
   
print(f"{base_num} elevado a {exponente_num} = {num_multiplicado}")
# Out:
# 4 elevado a 4 = 256

# %%
base_num=int(input("Ingrese número base: "))
exponente_num=int(input("Ingrese número exponencial"))
num_multiplicado = base_num

if exponente_num==0:
    print(f"{base_num} elevado a {exponente_num} = 1 ")
else:
    for i in range(1, exponente_num):
        num_multiplicado = num_multiplicado * base_num
    print(f"{base_num} elevado a {exponente_num} = {num_multiplicado}")

# %% [markdown]
# ### Ejercicio 9: El mayor de N números
# **Enunciado:** Crea un programa que primero pregunte cuántos números se capturarán y, con un `for`, lea cada uno guardando siempre el mayor visto hasta ese momento en una variable.
# **Entrada:** `6`, valores `4`, `15`, `3`, `9`, `21`, `7`
# **Proceso:** el máximo parcial va cambiando: `4 -> 15 -> 21`
# **Salida:** `El número mayor es: 21`

# %%
cantidad=int(input("Ingrese cantidad de números a capturar: "))
num_mayor= 0
i=1
for i in range (cantidad):
    numero_ingresado = int(input("Ingrese número base: "))
    if numero_ingresado >= num_mayor:
        num_mayor = numero_ingresado
print(num_mayor)

# %%
cantidad=int(input("Ingrese cantidad de números a capturar: "))
numero= int(input("Ingrese número: "))
num_mayor=numero
#Para que el número este dado por el usuario 
# y no setearlo en 0 ya que si se le ingresa num negativos no los va a poder comparar.
for i in range (cantidad-1):
    numero= int(input("Ingrese número: "))
    if numero >= num_mayor:
        num_mayor = numero
print(f"El número mayor es:{num_mayor}")
# Out:
# El número mayor es:-1

# %% [markdown]
# ### Ejercicio 10: Múltiplos de K con range y paso
# **Enunciado:** Crea un programa que pida dos enteros positivos `k` y `n`, e imprima en una sola línea todos los múltiplos de `k` menores que `n`, generándolos directamente con `range(k, n, k)` (sin usar `if`).
# **Entrada:** `k = 4`, `n = 30`
# **Proceso:** `range(4, 30, 4)` genera `4, 8, 12, 16, 20, 24, 28`
# **Salida:** `4, 8, 12, 16, 20, 24, 28`

# %%
k_nummulti= int(input("Ingrese número a multiplicar: "))
n_nummenor= int(input("Ingrese número al que debe ser menor: "))

for i in range(k_nummulti, n_nummenor, k_nummulti):
    print(f"{i} ", end="")
# Out:
# 4 8 12 16 20 24 28

# %% [markdown]
# ### Ejercicio 11: Serie alternada
# **Enunciado:** Crea un programa que pida un entero positivo `n` y calcule la suma alternada `1 - 2 + 3 - 4 + ...` hasta `n`. Usa un `for` y decide el signo de cada término con el módulo `%`.
# **Entrada:** `6`
# **Proceso:** `1 - 2 + 3 - 4 + 5 - 6 = -3`
# **Salida:** `El resultado de la serie es: -3`

# %%
# si es par menos % 2 = 0
# si es impar mas % 2 !=0
n=int(input("Ingrese numero positivo"))
resultado=0

for num in range (1, n + 1 ):
    print("num vale", num)
    if num % 2 == 0:
        resultado -= num 
        print(f"si es resta: - {num}")
       
    else:
        resultado += num
        print(f"si es suma: + {num}")
print(f"El resultado de la series es: {resultado}")
# Out:
# num vale 1
# si es suma: + 1
# num vale 2
# si es resta: - 2
# num vale 3
# si es suma: + 3
# num vale 4
# si es resta: - 4
# num vale 5
# si es suma: + 5
# num vale 6
# si es resta: - 6
# El resultado de la series es: -3

# %% [markdown]
# ### Ejercicio 12: Serie armónica
# **Enunciado:** Crea un programa que pida un entero positivo `n` y calcule la suma `1 + 1/2 + 1/3 + ... + 1/n` con un acumulador flotante. Muestra el resultado con 2 decimales.
# **Entrada:** `4`
# **Proceso:** `1 + 0.5 + 0.3333... + 0.25 = 2.0833...`
# **Salida:** `La suma de la serie es: 2.08`

# %%
n=int(input("Ingrese numero positivo"))
resultado=0.0
for num in range (1, n + 1):
    resultado += 1 / num
print(f"La suma de la serie es: {resultado:.2f}")
# Out:
# La suma de la serie es: 2.08

# %% [markdown]
# ### Ejercicio 13: Sucesión de Fibonacci
# **Enunciado:** Crea un programa que pida cuántos términos de la sucesión de Fibonacci mostrar. La sucesión comienza con `0` y `1`, y cada término siguiente es la suma de los dos anteriores. Usa dos variables que avancen junto con el `for`.
# **Entrada:** `8`
# **Proceso:** `0+1=1`, `1+1=2`, `1+2=3`, `2+3=5`, `3+5=8`, `5+8=13`
# **Salida:** `Fibonacci: 0, 1, 1, 2, 3, 5, 8, 13`S

# %%
cantidad=int(input("Ingrese cantidad de números a mostrar del número Fibonacci: "))
num1=0
num2=1
for num in range (0, cantidad, num2):
    if num % 2 == 0:
        num1 = num1 + num2
        
        print(num1)
    else:
        num2 = num2 + num1
        
        print(num2)

# %%
cantidad=int(input("Ingrese cantidad de números a mostrar del número Fibonacci: "))
num1=0
num2=1
for num in range (cantidad):
    print(f"{num1} ", end="")
    suma = num1 + num2
    #1 #2 #3
    #este es el que se imprime, y el que se mantiene
    num1 = num2
    #1 #1 #2 
    #es la suma de ambos numeros
    num2 = suma
    #1 #2 #3
# Out:
# 0 1 1 2 3 5 8 13

# %%
cantidad=int(input("Ingrese cantidad de números a mostrar del número Fibonacci: "))
num1=0
num2=1
for num in range (cantidad):
    print(f"{num1} ", end="")
    suma = num1 + num2
    #1, #1, 2, 3
    num2 = num1
    #0, #1, 1, 
    num1 = suma
    #1, #1, 2,
# Out:
# 0 1 1 2 3 5

# %% [markdown]
# ### Ejercicio 14: Triángulo de asteriscos
# **Enunciado:** Crea un programa que pida un número de filas y dibuje un triángulo de asteriscos cuya primera fila tenga 1 asterisco, la segunda 2, y así sucesivamente. Usa ciclos anidados.
# **Entrada:** `4`
# **Salida:**
# ```
# *
# **
# ***
# ****
# ```
#
# ---

# %%
#
#asterisco es igual a 2*i-1
filas=int(input("Ingrese altura: ")) 
for fila in range(1, filas + 1):
    for espacio in range (filas - fila):
        print(" ", end="")
    for asterisco in range ((2 * fila) - 1):
        print("*", end="")

    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %% [markdown]
# ## BLOQUE 5 · RETOS DE INTEGRACIÓN (DECISIÓN + CICLOS)
#
# ### Ejercicio 16: Adivina el número secreto
# **Enunciado:** Define en tu código un número secreto (por ejemplo `42`). El usuario intenta adivinarlo en un ciclo `while`: por cada intento muestra `Muy bajo` si su número es menor, `Muy alto` si es mayor, y al acertar termina indicando en cuántos intentos lo logró (usa un contador).
# **Entrada:** `10`, `90`, `40`, `42`
# **Proceso:** `10 < 42` (bajo), `90 > 42` (alto), `40 < 42` (bajo), `42 == 42` (correcto)
# **Salida:**
# ```
# Muy bajo
# Muy alto
# Muy bajo
# ¡Correcto! Lo lograste en 4 intentos
# ```

# %%
numsecreto = 42
contador=1
num_usurario=int(input("Ingrese numero: "))
while num_usurario != numsecreto:
    contador += 1
    if num_usurario > numsecreto:
        print("Tu número es muy alto")
    elif num_usurario < numsecreto:
        print("Tu número es muy bajo")
    num_usurario=int(input("Intenta de nuevo.\nIngrese numero: "))

print(f"¡Correcto! Lo lograste en {contador} intentos")
# Out:
# tu número es muy bajo
# Tu número es muy alto
# tu número es muy bajo
# ¡Correcto! Lo lograste en 4 intentos

# %% [markdown]
# ### Ejercicio 17: Detector de números primos
# **Enunciado:** Crea un programa que pida un entero positivo y determine si es primo (solo divisible entre 1 y sí mismo). Recorre los posibles divisores con un `for` desde 2 hasta `n - 1`, cuenta cuántos dividen exactamente con `%` y decide el mensaje.
# **Entrada:** `29`
# **Proceso:** ningún número de `2` a `28` divide exactamente a `29` (contador de divisores = 0)
# **Salida:** `29 es primo`

# %%
num = int(input("Ingrese numero: "))

if num<=1:
    print(f"{num} NO es número primo")
else: 
    contador = 2
    for i in range(2, num):
        if num % i == 0:
            contador += 1

    if contador == 2:
        print(f"{num} es número primo")
    else:
        print(f"{num} NO es número primo, es divisible en {contador} cantidad de números")
# Out:
# 6 NO es número primo, es divisible en 4 cantidad de números

# %% [markdown]
# ### Ejercicio 18: Número perfecto
# **Enunciado:** Un número perfecto es igual a la suma de sus divisores propios (sin contarse a sí mismo). Crea un programa que pida un entero positivo, sume sus divisiores con un `for` y un acumulador, e indique si es perfecto o no.
# **Entrada:** `28`
# **Proceso:** divisores propios `1, 2, 4, 7, 14`; suma = `28`
# **Salida:** `28 es un número perfecto`

# %% [markdown]
# ### Ejercicio 19: Interés compuesto año por año
# **Enunciado:** Crea un programa que pida un capital inicial, una tasa de interés anual en porcentaje y un número de años. Con un `for`, muestra el capital al final de cada año aplicando el crecimiento sobre el año anterior, y al final reporta el capital total.
# **Entrada:** capital `1000`, tasa `10`, años `3`
# **Proceso:** `1000 * 1.10 = 1100`, `1100 * 1.10 = 1210`, `1210 * 1.10 = 1331`
# **Salida:**
# ```
# Año 1: $1100.00
# Año 2: $1210.00
# Año 3: $1331.00
# Capital final: $1331.00

# %%
capital=int(input("Ingrese Capital inicial"))
tasaInteres=int(input("Ingrese Capital inicial"))

# %% [markdown]
# ### Ejercicio 20: Simulador de batería
# **Enunciado:** Simula la descarga de la batería de un laptop que inicia al 100% y pierde 10 puntos por hora. Con un `while`, muestra el nivel después de cada hora; cuando el nivel llegue a 20% o menos, imprime la advertencia de batería baja y detén la simulación.
# **Entrada:** Ninguna (la simulación inicia siempre en 100).
# **Proceso:** niveles `90, 80, 70, 60, 50, 40, 30, 20`; al llegar a `20` se dispara la alerta
# **Salida:**
# ```
# Hora 1: 90%
# Hora 2: 80%
# Hora 3: 70%
# Hora 4: 60%
# Hora 5: 50%
# Hora 6: 40%
# Hora 7: 30%
# Hora 8: 20%
# ¡Batería baja! Conecta el cargador
# ```
# **Tip:** Usa `time.sleep(10)` para pausar 10 segundos el ciclo simulando que es una hora. Recuerda importar `import time`
