# %% [markdown]
# #### Ejercicio 1: Área de un triángulo
# Escribe un programa en Python que aplique el modelo Entrada-Proceso-Salida para calcular el área de un triángulo (`area = (base * altura) / 2`), usando `input()`, `float()` y `print()`.
# **Entrada:** `base = 8`, `altura = 5`
# **Salida:** `El área del triángulo es: 20.0`

# %%
base = float(input("Ingrese base del triángulo: "))
altura = float(input("Ingrese altura del triángulo: "))
area = (base * altura) / 2
print(f"El área del tríangulo es: {area:.1f}")
# Out:
# El área del tríangulo es: 20.0

# %% [markdown]
# #### Ejercicio 2: Conversión de Celsius a Fahrenheit
# Escribe un programa en Python que pida una temperatura en grados Celsius y la convierta a Fahrenheit (`F = C * 9/5 + 32`).
# **Entrada:** `celsius = 30`
# **Salida:** `30 grados Celsius equivalen a 86.0 grados Fahrenheit`

# %%
celsius =int(input("Ingrese temperatura en celsius: "))
fahrenheit = (celsius * 9/5)+ 32
print(f"{celsius}° Celsius equivalen a {fahrenheit}° Fahrenheit")
# Out:
# 30° Celsius equivalen a 86.0° Fahrenheit

# %% [markdown]
# #### Ejercicio 3: Interés simple (antes en PSeInt)
# Escribe un programa en Python que pida capital, tasa y tiempo, y calcule el interés simple (`interes = capital * (tasa / 100) * tiempo`).
# **Entrada:** `capital = 2000`, `tasa = 6`, `tiempo = 2`
# **Salida:** `El interés simple es: 240.0`

# %% [markdown]
# Algoritmo Interés
#     Escribir "Ingrese el capital: "
#
#     Leer capital
#
#     Escribir "Ingrese la tasa de interés: "
#
#     Leer tasa
#
#     Escribir "Ingrese el tiempo: "
#
#     Leer tiempo
#
#     interes <- capital * (tasa / 100) * tiempo
#
#     Escribir "El interés simple es: ", interes
#
# FinAlgoritmo

# %%
capital = float(input("Ingrese el capital: "))
tasa = float(input("Ingrse la tasa de interés: "))
tiempo =  float(input("Ingrese el tiempo: "))
interes = capital * (tasa / 100) * tiempo
print(f"El interés simple es: {interes}")
# Out:
# El interés simple es: 240.0

# %% [markdown]
# ## BLOQUE 2 · TEMAS 3 Y 4: VARIABLES, OPERADORES Y ENTRADA/SALIDA

# %% [markdown]
# #### Ejercicio 4: Precedencia de operadores (antes de análisis teórico)
# Escribe un programa en Python que calcule `4 * 3 + 10 // 3 - 8 % 5`, muestre el resultado y **imprima el orden de evaluación aplicado** (`12 + 3 - 3`).
# **Salida:**
# ```
# 4 * 3 + 10 // 3 - 8 % 5 = 12 + 3 - 3 = 12
# ```

# %%
Op = 4 * 3 + 10 // 3 - 8 % 5
# Por jerarquia 
# 4 * 3 = 12    10 // 3 =3  Y  8 % 5 = 3
# Después
# 12 + 3 -3
# 15 -3
# 12
print("El resultado de la operacion \"4 * 3 + 10 // 3 - 8 % 5\" es: ", Op)
# Out:
# El resultado de la operacion "4 * 3 + 10 // 3 - 8 % 5" es:  12

# %% [markdown]
# #### Ejercicio 5: Casting tras `input()` (antes de análisis teórico)
# Escribe un programa en Python que pida un número con `input()`, demuestre que devuelve `str` (`type()`), intente `x + 1` dentro de `try-except` capturando `TypeError`, y finalmente haga `int(x)` para sumar y obtener el resultado correcto.

# %% [markdown]
# ### Explicación
# La variable x guarda un tipo de dato de texto (str). Al intentar ejecutar x + 1, el programa genera un TypeError porque no es posible sumar una cadena de texto con un número entero. Para corregirlo, se debe modificar la línea a x = int(input("Número: ")), lo cual convierte el dato ingresado de str a int.

# %%
x = input ("Ingrese un número: ")
print("x es tipo", type(x))

try:
    suma = x + 1
except TypeError:
    print("No es posible sumar una cadena de texto con un número entero.")

suma_correcta= int(x) + 1
print(f"El resultado de la suma es: {suma_correcta}")
# Out:
# x es tipo <class 'str'>
# No es posible sumar una cadena de texto con un número entero.
# El resultado de la suma es: 26

# %% [markdown]
# #### Ejercicio 6: Conversión de horas a segundos
# Crea un programa que pida una cantidad de horas (`float`) y la convierta a segundos (1 hora = 3600 segundos), mostrando el resultado formateado.
# **Entrada:** `3`
# **Salida:** `3 horas equivalen a 10800 segundos`

# %%
horas = float(input("Ingrese cantidad de horas: "))
segundos = horas * 3600
print (f"{horas} horas equivalen a {segundos:.2f} segundos")
# Out:
# 3.0 horas equivalen a 10800.00 segundos

# %% [markdown]
# ### Ejercicio 7: Descuento del 15% con f-strings
# **Enunciado:** Crea un programa que pida el precio de un artículo y aplique un 15% de descuento, mostrando el monto del descuento y el precio final con dos decimales usando f-strings.
# **Entrada:** `460`
# **Proceso:** `descuento = 460 * 0.15`, `final = 460 - 69`
# **Salida:**
# ```
# Descuento (15%): $69.00
# Precio final: $391.00

# %%
precio = float(input("Ingrese el precio del artículo: "))
descuento = precio * 0.15
precioFinal = precio - descuento
print(f"Descuento (15%): {descuento:.2f}")
print(f"Precio final: {precioFinal:.2f}")
# Out:
# Descuento (15%): 69.00
# Precio final: 391.00

# %% [markdown]
# ## BLOQUE 3 · TEMAS 5, 6, 7 Y 8: DECISIONES, CICLOS Y DEBUGGING
#
# ### Ejercicio 8: Número par o impar
# **Enunciado:** Crea un programa que pida un número entero y determine con `if-else` y el operador `%` si es par o impar.
# **Entrada:** `17`
# **Proceso:** `17 % 2 = 1`
# **Salida:** `17 es un número impar`

# %%
numero = int(input("Ingrese número: "))

if numero % 2 == 1:
    print(f"El número {numero} es impar")
else: 
    print(f"El número {numero} es par")
# Out:
# El número 17 es impar

# %% [markdown]
# ### Ejercicio 9: Mayor de tres números
# **Enunciado:** Crea un programa que pida tres números y determine cuál es el mayor usando `if-elif-else`.
# **Entrada:** `12`, `45`, `23`
# **Salida:** `El mayor de los tres números es: 45`

# %%
num1 = int(input("Ingrese el primer número: "))
num2 = int(input("Ingrese el segundo número: "))
num3 = int(input("Ingrese el tercer número: "))

if num1 >= num2 and num1 >= num3:
    print(f"El mayor de los tres números es: {num1}")
elif num2 >= num1 and num2 >= num3:
    print(f"El mayor de los tres números es: {num2}")
else:
    print(f"El mayor de los tres números es: {num3}")
# Out:
# El mayor de los tres números es: 45

# %% [markdown]
# ### Ejercicio 10: Suma acumulada con `while`
# **Enunciado:** Crea un programa que sume números ingresados por el usuario mientras el número sea distinto de `0` (el `0` no se suma y termina el ciclo).
# **Entrada:** `5`, `8`, `2`, `0`
# **Proceso:** `5 + 8 + 2 = 15`
# **Salida:** `La suma de los números es: 15`

# %%
suma = 0
while True:
    numero_sum = float(input("El 0 termina el ciclo.\nIngresa número a sumar: "))
    if numero_sum == 0:
        break
    else: 
        suma += numero_sum

print(f"La suma de los números es: {suma}")
# Out:
# La suma de los números es: 15.0

# %% [markdown]
# ### Ejercicio 11: Tabla de multiplicar con `for`
# **Enunciado:** Crea un programa que pida un número entero y muestre su tabla de multiplicar del 1 al 10 usando un ciclo `for` y `range()`.
# **Entrada:** `6`
# **Salida:**
# ```
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
#
# ```

# %%
numero_tmultiplicar = int(input("Ingrese número del que desea su tabla de multiplicar: "))

for n in range (1,11):
    multipli= numero_tmultiplicar * n
    print(f"{numero_tmultiplicar} x {n} = {multipli}")
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# #### Ejercicio 12: Suma de pares del 1 al 20 con `for` y `continue`
# **Salida:** `La suma de los números pares del 1 al 20 es: 110`

# %%
suma = 0
for n in range (1, 21):
    if n % 2 == 0:
        suma += n
    else:
        continue
print(f"La suma de los números pares del 1 al 20 es: {suma}")
# Out:
# La suma de los números pares del 1 al 20 es: 110

# %% [markdown]
# #### Ejercicio 13: Suma de una lista con función que regresa valor (sin `sum()`)
# **Entrada:** `[10, 20, 30, 40]` → **Salida:** `La suma de los elementos es: 100`

# %%
def suma_lista(lista):
    suma = 0
    for elemento in lista:
        suma += elemento
    return suma

lista = [10, 20, 30, 40]
print("La suma de los elementos es: ", suma_lista(lista))
# Out:
# La suma de los elementos es:  100

# %% [markdown]
# ### Ejercicio 14: Máximo de una lista con función que regresa valor
# **Enunciado:** Escribe una función que reciba una lista de números y **regrese** el valor máximo recorriéndola con un ciclo (sin usar `max()`).
# **Entrada:** `lista = [7, 3, 9, 2]`
# **Salida:** `El elemento máximo es: 9`

# %%
def lista_numeros(cantidad):
    lista = []
    for d in range (1, cantidad +  1):
        num = int(input("Ingrese un numero"))
        lista.append(num)
        if d == 1:
            num_maximo = num
        if num >= num_maximo:
            num_maximo = num
        
    return num_maximo

num_lista= int(input("Ingrese cantidad numeros: "))
lista_numeros(num_lista)
# Out:
# 0

# %%
def num_max (lista):
    num_max = lista[0]
    for elemento in lista:
        if elemento >= num_max:
            num_max = elemento
    return num_max

lista = [7, 3, 9, 2]

print(f"El elemento máximo es: {num_max(lista)}")
# Out:
# El elemento máximo es: 9

# %% [markdown]
# #### Ejercicio 15: Matriz y suma de la diagonal principal
# **Entrada:** `[[1,2,3],[4,5,6],[7,8,9]]` → **Salida:** `La suma de la diagonal principal es: 15`

# %%
matriz = [[1,2,3],[4,5,6],[7,8,9]]

# %% [markdown]
# #### Ejercicio 16: Promedio con función que no regresa valor
# **Entrada:** `[8, 9, 10, 7]` → **Salida:** `El promedio es: 8.50`

# %%
def calcular_promedio(lista):
    promedio = 0
    suma_calif=0
    for calif in lista:
        suma_calif += calif
    promedio = suma_calif / len(lista)
    print(f"El promedio es {promedio:.2f}")

calificaciones = [8, 9, 10, 7]
calcular_promedio(calificaciones)
# Out:
# El promedio es 8.50

# %% [markdown]
# #### Ejercicio 17: Invertir una lista con slicing
# **Entrada:** `[1, 2, 3, 4, 5]` → **Salida:** `Lista invertida: [5, 4, 3, 2, 1]

# %%
lista  = [1, 2, 3, 4, 5]
lista_invertida = lista[::-1]
print(f"Lista invertida: {lista_invertida}" )
# Out:
# Lista invertida: [5, 4, 3, 2, 1]

# %% [markdown]
# ### Ejercicio 18: Factorial con función recursiva
# **Enunciado:** Escribe una función recursiva que calcule el factorial de un número (`n! = n * (n-1) * ... * 1`) y regrese el resultado. Considera que `0! = 1`.
# **Entrada:** `5`
# **Proceso:** `5 * 4 * 3 * 2 * 1 = 120`
# **Salida:** `El factorial de 5 es: 120`

# %% [markdown]
# ### BLOQUE 5 · TEMAS 13, 14, 15 Y 16: TUPLAS, DICCIONARIOS, EXCEPCIONES Y STRINGS
#
# #### Ejercicio 19: Tupla: acceso y suma con función
# **Entrada:** `(4, 8, 15, 16, 23, 42)` → **Salida:**
# ```
# El tercer elemento es: 15
# La suma de la tupla es: 108
# ```

# %% [markdown]
# #### Ejercicio 20: Diccionario: buscar teléfono de un contacto
# **Entrada:** `Beto` → **Salida:** `El teléfono de Beto es: 5555678`

# %% [markdown]
# #### Ejercicio 21: Diccionario de calificaciones y promedios
# **Entrada:** `{"Ana": [8, 9, 10], "Beto": [7, 7, 8]}` → **Salida:**
# ```
# Ana: 9.00
# Beto: 7.33

# %% [markdown]
# #### Ejercicio 22: Excepción de división entre cero
# **Entrada:** `10`, `0` → **Salida:** `Error: No se puede dividir entre cero.`

# %%
try:
    dividendo = int(input("Ingrese dividendo: "))
    divisor = int(input("Ingrese divisor: "))
    division = dividendo / divisor
    print("El resultado de la división es:", division)
except ZeroDivisionError:
    print("No se puede dividir entre cero.")
# Out:
# El resultado de la división es: 0.8

# %% [markdown]
# ### Ejercicio 23: Excepción de valor no numérico
# **Enunciado:** Crea un programa que pida un número entero y lo convierta con `int()` dentro de un bloque `try-except`, capturando `ValueError` para mostrar un mensaje amigable si el usuario escribe algo que no es un número.
# **Entrada:** `"abc"`
# **Salida:** `Error: Debes ingresar un número entero.`

# %%
try: 
    num = int(input("Ingresa un número entero:")) 
except ValueError:
    print("Error: Debes ingresar un número entero.")

# %% [markdown]
# ### Ejercicio 24: Contar palabras de un string
# **Enunciado:** Escribe un programa que cuente cuántas palabras tiene un mensaje usando el método `.split()` y la función `len()`.
# **Entrada:** `"Python es un lenguaje de programacion"`
# **Proceso:** `len("Python es un lenguaje de programacion".split()) = 6`
# **Salida:** `El mensaje tiene 6 palabras.`

# %%
mensaje = "Python es un lenguaje de programación"
print("El mensaje tiene", len(mensaje.split()) , "palabras")
# Out:
# El mensaje tiene 6 palabras

# %% [markdown]
# ### Ejercicio 25: Longitud, mayúsculas y reemplazo de un string
# **Enunciado:** Dado el mensaje `"aprende python"`, muestra su longitud con `len()`, su versión en mayúsculas con `.upper()` y el resultado de reemplazar `"python"` por `"programacion"` con `.replace()`.
# **Entrada:** `"aprende python"`
# **Proceso:** `len("aprende python") = 14`, `.upper()` = `"APRENDE PYTHON"`, `.replace("python", "programacion")` = `"aprende programacion"`
# **Salida:**
# ```
# Longitud: 14
# En mayúsculas: APRENDE PYTHON
# Reemplazo: aprende programacion
# ```

# %%
mensaje = "Aprende python"
print("Longitud: ", len(mensaje))
print("En mayúsculas: ", mensaje.upper())
print("Reemplazo: ", mensaje.replace("python", "programación"))
# Out:
# Longitud:  14
# En mayúsculas:  APRENDE PYTHON
# Reemplazo:  Aprende programación
