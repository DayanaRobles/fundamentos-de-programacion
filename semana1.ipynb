# %% [markdown]
# # Sesion 1
# Este archivo es para 2 cosas
# 1. Familiarizarnos con Jupyter Notebook.
# 2. practicar python

# %%
print ("Hola Mundo!")
# Out:
# Hola Mundo!

# %% [markdown]
# ## variables
# Las variables en python son tipos de datos que tienen diferente forma
# Están las variables
# Numericas
#     enteros
#     Flotantes
# Cadena de caracteres
# Booleanas
# Compuesto

# %%
nombre="Alien"
edad= 43
es_estudiante= True
esta_activo=False
print (type(nombre))
print(type(edad))
print(type(esta_activo))

# %% [markdown]
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'nonetype'>

# %%
nombre="Alien"
edad= 43
print("hola",nombre, "ya vi que tienes", edad,"años de edad" )

# %% [markdown]
# En este punto, Inicialicé el proyecto en Git.
